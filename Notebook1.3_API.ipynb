# %% [markdown]
# # Consumo de datos a través de APIs

# %% [markdown]
# ## CASO 1: No requiere autenticación
#
# ### Proveedor: Workd Bank
#
# <b>Documentación de la API</b>: https://datahelpdesk.worldbank.org/knowledgebase/articles/889392-about-the-indicators-api-documentation
#
# The Indicators API provides access to over 45 databases, including:
#
#     World Development Indicators
#     International Debt Statistcs
#     Doing Business
#     Human Capital Index
#     Subnational Poverty
#     And many more

# %%
import requests

endpoint = "http://api.worldbank.org/v2/country/" # Búsqueda por país

def get_info_country(country_code):
    url = endpoint + country_code + "?format=json"  # URL de la solicitud (código país y format)
    result = requests.get(url)  # Realizamos la solicitud GET a la API
    
    if result.status_code == 200:  # Si la solicitud es exitosa (código de estado 200)
        data = result.json()  # Convertimos la respuesta a formato JSON
        # Extraemos la información del primer país de la lista
        # (podría haber más de uno con el mismo nombre)
        print(data)
        pais = data[1]
        print('\n', pais)
        
        # Mostramos información básica sobre el país
        print("\nInformación sobre", country_code, ":")
        print("Id: ", pais[0]['id'])
        print("Name: ", pais[0]['name'])
        print("Capital: ", pais[0]['capitalCity'])
        print("Region: ", pais[0]['region']['value'])
    else:
        print("No se pudo obtener información sobre", nombre_pais)

# Ejemplo de uso: obtener información sobre Ecuador
get_info_country("ec")
# Out:
# [{'page': 1, 'pages': 1, 'per_page': '50', 'total': 1}, [{'id': 'ECU', 'iso2Code': 'EC', 'name': 'Ecuador', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': 'LAC', 'iso2code': 'XJ', 'value': 'Latin America & Caribbean (excluding high income)'}, 'incomeLevel': {'id': 'UMC', 'iso2code': 'XT', 'value': 'Upper middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Quito', 'longitude': '-78.5243', 'latitude': '-0.229498'}]]
#
#  [{'id': 'ECU', 'iso2Code': 'EC', 'name': 'Ecuador', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': 'LAC', 'iso2code': 'XJ', 'value': 'Latin America & Caribbean (excluding high income)'}, 'incomeLevel': {'id': 'UMC', 'iso2code': 'XT', 'value': 'Upper middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Quito', 'longitude': '-78.5243', 'latitude': '-0.229498'}]
#
# Información sobre ec :
# Id:  ECU
# Name:  Ecuador
# Capital:  Quito
# Region:  Latin America & Caribbean

# %% [markdown]
# ## CASO 2: Requiere un API token
#
# ### Proveedor: SerpApi
#
# Documentación de la API: https://serpapi.com/search-api
#
#
# #### Caso 2.1: Uso del método search:
#
# <i>search API endpoint allows you to scrape the results from Google search engine via our SerpApi service. Head to the playground for a live and interactive demo. You can query https://serpapi.com/search using a GET request.</i>

# %%
#!pip install google-search-results # Instalar antes la librería

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google",
  "q": "tourism", # palabra clave
  "hl": "es",  # lenguaje
  "gl": "ec", # dominio de google
  "api_key": ""
}

search = GoogleSearch(params)
results = search.get_dict()
print("Diccionario: ", results.keys(), "\n\n")
organic_results = results["organic_results"]
organic_results
# Out:
# Diccionario:  dict_keys(['search_metadata', 'search_parameters', 'search_information', 'inline_images_suggested_searches', 'inline_images', 'related_questions', 'organic_results', 'related_searches', 'pagination', 'serpapi_pagination'])
# [{'position': 1,
#   'title': 'Turismo - Wikipedia, la enciclopedia libre',
#   'link': 'https://es.wikipedia.org/wiki/Turismo',
#   'redirect_link': 'https://www.google.comhttps://es.wikipedia.org/wiki/Turismo',
#   'displayed_link': 'https://es.wikipedia.org › wiki › Turismo',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1dfbd0998a634039866daa457f854c8e977.png',
#   'snippet': 'Turismo\u200b es un término que comprende las actividades que realizan las personas durante sus viajes y estancias en lugares distintos a su entorno habitual ...',
#   'source': 'Wikipedia'},
#  {'position': 2,
#   'title': 'Tourism | Definition, History, Types, Importance, & ...',
#   'link': 'https://www.britannica.com/topic/tourism',
#   'redirect_link': 'https://www.google.comhttps://www.britannica.com/topic/tourism',
#   'displayed_link': 'https://www.britannica.com › topic',
#   'thumbnail': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1dfb9e60bebd6a4ac69c598491fb5605ceb.jpeg',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1df44c0682a089261d6eeb8e58ff30070e4.png',
#   'date': 'hace 3 días',
#   'snippet': 'Tourism, the act and process of spending time away from home in pursuit of recreation, relaxation, and pleasure, while making use of the ...',
#   'snippet_highlighted_words': ['Tourism'],
#   'source': 'Britannica'},
#  {'position': 3,
#   'title': 'Tourism',
#   'link': 'https://en.wikipedia.org/wiki/Tourism',
#   'redirect_link': 'https://www.google.comhttps://en.wikipedia.org/wiki/Tourism',
#   'displayed_link': 'https://en.wikipedia.org › wiki',
#   'thumbnail': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1df925cffc80169474b293a9104f26de6db.jpeg',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1df458c81cd81782521d53b747eee349244.png',
#   'snippet': 'Tourism is travel for pleasure, and the commercial activity of providing and supporting such travel.UN Tourism defines tourism more generally, ...',
#   'snippet_highlighted_words': ['Tourism', 'Tourism', 'tourism'],
#   'source': 'Wikipedia'},
#  {'position': 4,
#   'title': 'Definición de tourism - Diccionario Inglés Collins',
#   'link': 'https://www.collinsdictionary.com/es/diccionario/ingles/tourism',
#   'redirect_link': 'https://www.google.comhttps://www.collinsdictionary.com/es/diccionario/ingles/tourism',
#   'displayed_link': 'https://www.collinsdictionary.com › diccionario › ingles',
#   'thumbnail': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1df76d7a4cf6b13770c2a19910d7611deea.jpeg',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1dfc436ca1bd032e566fd81dd130d7321eb.png',
#   'snippet': 'Tourism is the business of providing services for people on holiday, for example hotels, restaurants, and trips. Tourism is vital for the ...',
#   'snippet_highlighted_words': ['Tourism', 'Tourism'],
#   'source': 'Collins Dictionary'},
#  {'position': 5,
#   'title': 'Traducción de tourism – Diccionario Inglés-Español',
#   'link': 'https://dictionary.cambridge.org/es/diccionario/ingles-espanol/tourism',
#   'redirect_link': 'https://www.google.comhttps://dictionary.cambridge.org/es/diccionario/ingles-espanol/tourism',
#   'displayed_link': 'https://dictionary.cambridge.org › ingles-espanol › tour...',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1dfe5e7e639050e07f6fd801621e7176112.jpeg',
#   'snippet': 'traducir TOURISM: turismo, turismo [masculine, singular]. Más información en el diccionario inglés-español.',
#   'snippet_highlighted_words': ['TOURISM'],
#   'source': 'Cambridge Dictionary'},
#  {'position': 6,
#   'title': 'Glossary of tourism terms',
#   'link': 'https://www.unwto.org/glossary-tourism-terms',
#   'redirect_link': 'https://www.google.comhttps://www.unwto.org/glossary-tourism-terms',
#   'displayed_link': 'https://www.unwto.org › glossary...',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1df572995dc4929278ffc2db627dca46a02.png',
#   'snippet': 'Tourism is a social, cultural and economic phenomenon which entails the movement of people to countries or places outside their usual environment for ...',
#   'snippet_highlighted_words': ['Tourism'],
#   'source': 'UNWTO'},
#  {'position': 7,
#   'title': 'Significado de tourism en inglés - Cambridge Dictionary',
#   'link': 'https://dictionary.cambridge.org/es/diccionario/ingles/tourism',
#   'redirect_link': 'https://www.google.comhttps://dictionary.cambridge.org/es/diccionario/ingles/tourism',
#   'displayed_link': 'https://dictionary.cambridge.org › ...',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1df38be12c8ed2ebb1d18b5b30ce84699a1.jpeg',
#   'snippet': "the business of providing services such as transport, places to stay, or entertainment for people on holiday: Tourism is Venice's main industry ...",
#   'snippet_highlighted_words': ['Tourism'],
#   'source': 'Cambridge Dictionary'},
#  {'position': 8,
#   'title': 'UN Tourism | Bringing the world closer',
#   'link': 'https://www.unwto.org/',
#   'redirect_link': 'https://www.google.comhttps://www.unwto.org/',
#   'displayed_link': 'https://www.unwto.org',
#   'thumbnail': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1dfb49617cd8f5670225bd2d83d5de00ee5.jpeg',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1df40f598b991048a6c9e66741493b91e1e.png',
#   'snippet': 'UN Tourism is the United Nations agency responsible for the promotion of responsible, sustainable and universally accessible tourism.',
#   'snippet_highlighted_words': ['Tourism', 'tourism'],
#   'sitelinks': {'inline': [{'title': 'Glossary of tourism terms',
#      'link': 'https://www.unwto.org/glossary-tourism-terms'},
#     {'title': 'Why Tourism?', 'link': 'https://www.unwto.org/why-tourism'},
#     {'title': 'About UN Tourism', 'link': 'https://www.unwto.org/who-we-are'},
#     {'title': 'Statistics of tourism',
#      'link': 'https://www.unwto.org/tourism-statistics'}]},
#   'source': 'UNWTO'},
#  {'position': 9,
#   'title': 'Ecuador Travel',
#   'link': 'https://ecuador.travel/',
#   'redirect_link': 'https://www.google.comhttps://ecuador.travel/',
#   'displayed_link': 'https://ecuador.travel',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSXt2taZQ_b9b6DkcM5QSu5BPRKKp9HTcJjR5Ptn8K7KZqcmQkYu6Hf&usqp=CAE&s',
#   'favicon': 'https://serpapi.com/searches/6623d95f2c687809cc00b509/images/15d09181636130a51756efc939bec1dff9f779afa0730ef713ec98e7cde1b580.png',
#   'snippet': 'Camina por exóticos senderos en la selva, relájate frente al mar, o vive experiencias inolvidables junto a las montañas. ¡Ecuador es para ti!',
#   'sitelinks': {'inline': [{'title': 'Best tourism villages',
#      'link': 'https://ecuador.travel/best-tourism-villages-ecuador/'},
#     {'title': 'Andes', 'link': 'https://ecuador.travel/andes/'},
#     {'title': 'Galápagos', 'link': 'https://ecuador.travel/galapagos/'},
#     {'title': 'Costa del pacífico',
#      'link': 'https://ecuador.travel/costa-del-pacifico/'}]},
#   'source': 'Ecuador Travel'}]

# %% [markdown]
# #### Caso 2.2: Uso del método search:
#
# <i> Our Google Trends API allows you to scrape results from the Google Trends search page. The API is accessed through the following endpoint: /search?engine=google_trends.</i>
#
# A user may query the following: https://serpapi.com/search?engine=google_trends utilizing a GET request. Head to the playground for a live and interactive demo.

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_trends",
  "q": "Quito,Loja,Galápagos",
  "data_type": "TIMESERIES",
  "api_key": ""
}


search = GoogleSearch(params)
results = search.get_dict()
interest_over_time = results["interest_over_time"]

# %%
interest_over_time
# Out:
# {'timeline_data': [{'date': 'Apr 16\u2009–\u200922, 2023',
#    'timestamp': '1681603200',
#    'values': [{'query': 'Quito', 'value': '24', 'extracted_value': 24},
#     {'query': 'Loja', 'value': '78', 'extracted_value': 78},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Apr 23\u2009–\u200929, 2023',
#    'timestamp': '1682208000',
#    'values': [{'query': 'Quito', 'value': '21', 'extracted_value': 21},
#     {'query': 'Loja', 'value': '78', 'extracted_value': 78},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Apr 30\u2009–\u2009May 6, 2023',
#    'timestamp': '1682812800',
#    'values': [{'query': 'Quito', 'value': '23', 'extracted_value': 23},
#     {'query': 'Loja', 'value': '74', 'extracted_value': 74},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'May 7\u2009–\u200913, 2023',
#    'timestamp': '1683417600',
#    'values': [{'query': 'Quito', 'value': '21', 'extracted_value': 21},
#     {'query': 'Loja', 'value': '78', 'extracted_value': 78},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'May 14\u2009–\u200920, 2023',
#    'timestamp': '1684022400',
#    'values': [{'query': 'Quito', 'value': '21', 'extracted_value': 21},
#     {'query': 'Loja', 'value': '76', 'extracted_value': 76},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'May 21\u2009–\u200927, 2023',
#    'timestamp': '1684627200',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '75', 'extracted_value': 75},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'May 28\u2009–\u2009Jun 3, 2023',
#    'timestamp': '1685232000',
#    'values': [{'query': 'Quito', 'value': '22', 'extracted_value': 22},
#     {'query': 'Loja', 'value': '81', 'extracted_value': 81},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Jun 4\u2009–\u200910, 2023',
#    'timestamp': '1685836800',
#    'values': [{'query': 'Quito', 'value': '25', 'extracted_value': 25},
#     {'query': 'Loja', 'value': '86', 'extracted_value': 86},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Jun 11\u2009–\u200917, 2023',
#    'timestamp': '1686441600',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '85', 'extracted_value': 85},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Jun 18\u2009–\u200924, 2023',
#    'timestamp': '1687046400',
#    'values': [{'query': 'Quito', 'value': '21', 'extracted_value': 21},
#     {'query': 'Loja', 'value': '79', 'extracted_value': 79},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Jun 25\u2009–\u2009Jul 1, 2023',
#    'timestamp': '1687651200',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '78', 'extracted_value': 78},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Jul 2\u2009–\u20098, 2023',
#    'timestamp': '1688256000',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '82', 'extracted_value': 82},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Jul 9\u2009–\u200915, 2023',
#    'timestamp': '1688860800',
#    'values': [{'query': 'Quito', 'value': '22', 'extracted_value': 22},
#     {'query': 'Loja', 'value': '81', 'extracted_value': 81},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Jul 16\u2009–\u200922, 2023',
#    'timestamp': '1689465600',
#    'values': [{'query': 'Quito', 'value': '22', 'extracted_value': 22},
#     {'query': 'Loja', 'value': '78', 'extracted_value': 78},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Jul 23\u2009–\u200929, 2023',
#    'timestamp': '1690070400',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '77', 'extracted_value': 77},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Jul 30\u2009–\u2009Aug 5, 2023',
#    'timestamp': '1690675200',
#    'values': [{'query': 'Quito', 'value': '24', 'extracted_value': 24},
#     {'query': 'Loja', 'value': '79', 'extracted_value': 79},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Aug 6\u2009–\u200912, 2023',
#    'timestamp': '1691280000',
#    'values': [{'query': 'Quito', 'value': '27', 'extracted_value': 27},
#     {'query': 'Loja', 'value': '85', 'extracted_value': 85},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Aug 13\u2009–\u200919, 2023',
#    'timestamp': '1691884800',
#    'values': [{'query': 'Quito', 'value': '22', 'extracted_value': 22},
#     {'query': 'Loja', 'value': '77', 'extracted_value': 77},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Aug 20\u2009–\u200926, 2023',
#    'timestamp': '1692489600',
#    'values': [{'query': 'Quito', 'value': '38', 'extracted_value': 38},
#     {'query': 'Loja', 'value': '78', 'extracted_value': 78},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Aug 27\u2009–\u2009Sep 2, 2023',
#    'timestamp': '1693094400',
#    'values': [{'query': 'Quito', 'value': '46', 'extracted_value': 46},
#     {'query': 'Loja', 'value': '74', 'extracted_value': 74},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Sep 3\u2009–\u20099, 2023',
#    'timestamp': '1693699200',
#    'values': [{'query': 'Quito', 'value': '23', 'extracted_value': 23},
#     {'query': 'Loja', 'value': '75', 'extracted_value': 75},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Sep 10\u2009–\u200916, 2023',
#    'timestamp': '1694304000',
#    'values': [{'query': 'Quito', 'value': '19', 'extracted_value': 19},
#     {'query': 'Loja', 'value': '73', 'extracted_value': 73},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Sep 17\u2009–\u200923, 2023',
#    'timestamp': '1694908800',
#    'values': [{'query': 'Quito', 'value': '24', 'extracted_value': 24},
#     {'query': 'Loja', 'value': '74', 'extracted_value': 74},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Sep 24\u2009–\u200930, 2023',
#    'timestamp': '1695513600',
#    'values': [{'query': 'Quito', 'value': '25', 'extracted_value': 25},
#     {'query': 'Loja', 'value': '73', 'extracted_value': 73},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Oct 1\u2009–\u20097, 2023',
#    'timestamp': '1696118400',
#    'values': [{'query': 'Quito', 'value': '28', 'extracted_value': 28},
#     {'query': 'Loja', 'value': '80', 'extracted_value': 80},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Oct 8\u2009–\u200914, 2023',
#    'timestamp': '1696723200',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '77', 'extracted_value': 77},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Oct 15\u2009–\u200921, 2023',
#    'timestamp': '1697328000',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '76', 'extracted_value': 76},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Oct 22\u2009–\u200928, 2023',
#    'timestamp': '1697932800',
#    'values': [{'query': 'Quito', 'value': '43', 'extracted_value': 43},
#     {'query': 'Loja', 'value': '80', 'extracted_value': 80},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Oct 29\u2009–\u2009Nov 4, 2023',
#    'timestamp': '1698537600',
#    'values': [{'query': 'Quito', 'value': '25', 'extracted_value': 25},
#     {'query': 'Loja', 'value': '78', 'extracted_value': 78},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Nov 5\u2009–\u200911, 2023',
#    'timestamp': '1699142400',
#    'values': [{'query': 'Quito', 'value': '26', 'extracted_value': 26},
#     {'query': 'Loja', 'value': '78', 'extracted_value': 78},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Nov 12\u2009–\u200918, 2023',
#    'timestamp': '1699747200',
#    'values': [{'query': 'Quito', 'value': '22', 'extracted_value': 22},
#     {'query': 'Loja', 'value': '84', 'extracted_value': 84},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Nov 19\u2009–\u200925, 2023',
#    'timestamp': '1700352000',
#    'values': [{'query': 'Quito', 'value': '23', 'extracted_value': 23},
#     {'query': 'Loja', 'value': '94', 'extracted_value': 94},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Nov 26\u2009–\u2009Dec 2, 2023',
#    'timestamp': '1700956800',
#    'values': [{'query': 'Quito', 'value': '27', 'extracted_value': 27},
#     {'query': 'Loja', 'value': '86', 'extracted_value': 86},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Dec 3\u2009–\u20099, 2023',
#    'timestamp': '1701561600',
#    'values': [{'query': 'Quito', 'value': '28', 'extracted_value': 28},
#     {'query': 'Loja', 'value': '94', 'extracted_value': 94},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Dec 10\u2009–\u200916, 2023',
#    'timestamp': '1702166400',
#    'values': [{'query': 'Quito', 'value': '26', 'extracted_value': 26},
#     {'query': 'Loja', 'value': '95', 'extracted_value': 95},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Dec 17\u2009–\u200923, 2023',
#    'timestamp': '1702771200',
#    'values': [{'query': 'Quito', 'value': '25', 'extracted_value': 25},
#     {'query': 'Loja', 'value': '100', 'extracted_value': 100},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Dec 24\u2009–\u200930, 2023',
#    'timestamp': '1703376000',
#    'values': [{'query': 'Quito', 'value': '18', 'extracted_value': 18},
#     {'query': 'Loja', 'value': '80', 'extracted_value': 80},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Dec 31, 2023\u2009–\u2009Jan 6, 2024',
#    'timestamp': '1703980800',
#    'values': [{'query': 'Quito', 'value': '22', 'extracted_value': 22},
#     {'query': 'Loja', 'value': '73', 'extracted_value': 73},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Jan 7\u2009–\u200913, 2024',
#    'timestamp': '1704585600',
#    'values': [{'query': 'Quito', 'value': '21', 'extracted_value': 21},
#     {'query': 'Loja', 'value': '83', 'extracted_value': 83},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Jan 14\u2009–\u200920, 2024',
#    'timestamp': '1705190400',
#    'values': [{'query': 'Quito', 'value': '19', 'extracted_value': 19},
#     {'query': 'Loja', 'value': '81', 'extracted_value': 81},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Jan 21\u2009–\u200927, 2024',
#    'timestamp': '1705795200',
#    'values': [{'query': 'Quito', 'value': '21', 'extracted_value': 21},
#     {'query': 'Loja', 'value': '76', 'extracted_value': 76},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Jan 28\u2009–\u2009Feb 3, 2024',
#    'timestamp': '1706400000',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '72', 'extracted_value': 72},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Feb 4\u2009–\u200910, 2024',
#    'timestamp': '1707004800',
#    'values': [{'query': 'Quito', 'value': '19', 'extracted_value': 19},
#     {'query': 'Loja', 'value': '72', 'extracted_value': 72},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Feb 11\u2009–\u200917, 2024',
#    'timestamp': '1707609600',
#    'values': [{'query': 'Quito', 'value': '17', 'extracted_value': 17},
#     {'query': 'Loja', 'value': '66', 'extracted_value': 66},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Feb 18\u2009–\u200924, 2024',
#    'timestamp': '1708214400',
#    'values': [{'query': 'Quito', 'value': '30', 'extracted_value': 30},
#     {'query': 'Loja', 'value': '68', 'extracted_value': 68},
#     {'query': 'Galápagos', 'value': '1', 'extracted_value': 1}]},
#   {'date': 'Feb 25\u2009–\u2009Mar 2, 2024',
#    'timestamp': '1708819200',
#    'values': [{'query': 'Quito', 'value': '32', 'extracted_value': 32},
#     {'query': 'Loja', 'value': '71', 'extracted_value': 71},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Mar 3\u2009–\u20099, 2024',
#    'timestamp': '1709424000',
#    'values': [{'query': 'Quito', 'value': '22', 'extracted_value': 22},
#     {'query': 'Loja', 'value': '72', 'extracted_value': 72},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Mar 10\u2009–\u200916, 2024',
#    'timestamp': '1710028800',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '69', 'extracted_value': 69},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Mar 17\u2009–\u200923, 2024',
#    'timestamp': '1710633600',
#    'values': [{'query': 'Quito', 'value': '20', 'extracted_value': 20},
#     {'query': 'Loja', 'value': '72', 'extracted_value': 72},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Mar 24\u2009–\u200930, 2024',
#    'timestamp': '1711238400',
#    'values': [{'query': 'Quito', 'value': '19', 'extracted_value': 19},
#     {'query': 'Loja', 'value': '69', 'extracted_value': 69},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Mar 31\u2009–\u2009Apr 6, 2024',
#    'timestamp': '1711843200',
#    'values': [{'query': 'Quito', 'value': '25', 'extracted_value': 25},
#     {'query': 'Loja', 'value': '70', 'extracted_value': 70},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Apr 7\u2009–\u200913, 2024',
#    'timestamp': '1712448000',
#    'values': [{'query': 'Quito', 'value': '27', 'extracted_value': 27},
#     {'query': 'Loja', 'value': '76', 'extracted_value': 76},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]},
#   {'date': 'Apr 14\u2009–\u200920, 2024',
#    'timestamp': '1713052800',
#    'values': [{'query': 'Quito', 'value': '24', 'extracted_value': 24},
#     {'query': 'Loja', 'value': '69', 'extracted_value': 69},
#     {'query': 'Galápagos', 'value': '<1', 'extracted_value': 0}]}],
#  'averages': [{'query': 'Quito', 'value': 24},
#   {'query': 'Loja', 'value': 78},
#   {'query': 'Galápagos', 'value': 0}]}
